# %%
from game import *
# Out:
# Please enter a size for the board:2121
# score: 0
#
#   G  *  *  *  *  *  *  *  *  G
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  P  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   G  *  *  *  *  *  *  *  *  G
#
# Please enter a direction for movement:2
# Invalid moves, please try again.
# Please enter a direction for movement:n
# Invalid moves, please try again.
# Please enter a direction for movement:N
# Invalid moves, please try again.
# Please enter a direction for movement:D
# score: 10
#
#   *  G  *  *  *  *  *  *  G  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *     *  *  *  *
#
#   *  *  *  *  *  P  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
# ...

# %%
def play():
    while True:
        opt = input("Start the game?")
        if opt == "Y":
            new_game = playGame()
            new_game.start_game()
        else:
            return

# %%
play()

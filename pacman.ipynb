# %%
import game

# %%
def play():
    while True:
        opt = input("Start the game?")
        if opt == "Y":
            new_game = playGame()
            new_game.start_game()
        else:
            return

# %%
play()
# Out:
# Start the game?Y
# Please enter a size for the board:15
# score: 0
#
#   G  *  *  *  *  *  *  *  *  *  *  *  *  *  G
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  P  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#
#   G  *  *  *  *  *  *  *  *  *  *  *  *  *  G
#
# Please enter a direction for movement:d
# Invalid moves, please try again.
# Please enter a direction for movement:D
# score: 10
#
# ...

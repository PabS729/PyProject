# %%
# Pacman in Python

## Project Discription

#This is a simplified version of pacman from the original game. 
#In this game, the player controls pacman in a square grid with dots around. 
#When the player moves the pacman around, the pacman eats the pac dots and scores. 
#There are also four ghosts in the game, trying to capture pacman as it moves. 

## How to Start

#To start the game, simply open pacman.ipynb in Jupyter Notebook, and run all the cells. 
# Hit "Y" when prompted to start the game
#The player will be prompted to enter a size for the board. The default size is 10. 
#There are five choices for the player to move the pacman. Controls are done via the keyboard.
    #- U: The pacman moves up one cell.
    #- D: The pacman moves down one cell.
    #- L: The pacman moves left one cell.
    #- R: The pacman moves right one cell.
    #- S: The pacman stays at the same spot.
#If the player hit other keys, the move will be invalid, and the player has to hit the valid keys again.

#All ghosts will move as the pacman moves. 
#If one of the ghosts capture pacman, the game ends. 
#The player will be prompted to start the game again. 
#Hit "Y" and the game starts again, otherwise, simply hit other keys and the program terminates.

# %%
from game import playGame
def play():
    while True:
        opt = input("Start the game?")
        if opt == "Y" or opt == "y":
            new_game = playGame()
            new_game.start_game()
        else:
            return

# %%
play()
# Out:
# Start the game?Y
# Please enter a size for the board:10
# score: 0
#
#   G  *  *  *  *  *  *  *  *  G
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  P  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   G  *  *  *  *  *  *  *  *  G
#
# Please enter a direction for movement:D
# score: 10
#
#   *  G  *  *  *  *  *  *  G  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *     *  *  *  *
#
#   *  *  *  *  *  P  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   G  *  *  *  *  *  *  *  *  G
#
#   *  *  *  *  *  *  *  *  *  *
#
# Please enter a direction for movement:D
# score: 20
#
#   *  *  G  *  *  *  *  G  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
#   *  *  *  *  *  *  *  *  *  *
#
# ...
